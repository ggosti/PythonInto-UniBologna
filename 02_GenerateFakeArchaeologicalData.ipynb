# %% [markdown]
# <a href="https://colab.research.google.com/github/ggosti/PythonInto-UniBologna/blob/main/02_GenerateFakeArchaeologicalData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd /content/drive/MyDrive/IntroPythonXArcheoBologna/
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/IntroPythonXArcheoBologna/'
# /content

# %%
import pandas as pd
import numpy as np

# %%
# Define possible values for each column
artifact_types = ['Pottery', 'Tool', 'Jewelry', 'Weapon', 'Statue']
sites = ['Pompeii', 'Stonehenge', 'Machu Picchu', 'Giza', 'Tikal']
num_records = 100  # Number of records to generate
conditions = ['Excellent', 'Good', 'Fair', 'Excellent', 'Poor']


# Generate random data
np.random.seed(42)  # For reproducibility
age = np.random.randint(100, 5000, num_records)
depth = age +  100*np.random.rand(num_records)
data = {
    'Artifact_Type': np.random.choice(artifact_types, num_records),
    'Age': age,  # Age in years
    'Stratigraphy_Depth': depth, # Depth in mm
    'Site': np.random.choice(sites, num_records),
    'Condition': np.random.choice(conditions, num_records)
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the first few rows
print(df.head())

# Save to a CSV file (optional)
df.to_csv('fake_archaeological_data.csv', index=False)
# Out:
#   Artifact_Type   Age  Stratigraphy_Depth          Site  Condition
# 0          Tool   960         1032.960618  Machu Picchu       Good
# 1       Pottery  3872         3935.755747    Stonehenge  Excellent
# 2        Weapon  3192         3280.721274       Pompeii  Excellent
# 3        Weapon   566          613.221493         Tikal       Fair
# 4       Pottery  4526         4537.959425          Giza  Excellent

# %%
df
# Out:
#    Artifact_Type   Age  Stratigraphy_Depth          Site  Condition
# 0           Tool   960         1032.960618  Machu Picchu       Good
# 1        Pottery  3872         3935.755747    Stonehenge  Excellent
# 2         Weapon  3192         3280.721274       Pompeii  Excellent
# 3         Weapon   566          613.221493         Tikal       Fair
# 4        Pottery  4526         4537.959425          Giza  Excellent
# ..           ...   ...                 ...           ...        ...
# 95       Pottery  3204         3215.347352    Stonehenge  Excellent
# 96       Jewelry  4698         4790.469362       Pompeii       Poor
# 97        Statue  2554         2641.733935         Tikal  Excellent
# 98          Tool  3745         3770.794163         Tikal       Poor
# 99          Tool   904          969.998405          Giza       Poor
#
# [100 rows x 5 columns]
